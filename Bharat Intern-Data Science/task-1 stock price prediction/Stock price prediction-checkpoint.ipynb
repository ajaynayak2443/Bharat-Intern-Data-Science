# %% [markdown]
# # Author: Ajay Nayak S

# %% [markdown]
# Data Science Intern @ Bharat Intern

# %% [markdown]
# Task : Stock Prediction

# %% [markdown]
# Dataset : Google Stock Prediction.
# The dataset is available at Kaggle : https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction

# %% [markdown]
# <b> Step 1: Import Required Packages</b>

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %% [markdown]
# <b>Step 2: Load the Data<b>

# %%
df = pd.read_csv(r"C:\Users\ajayn\Desktop\Bharat Intern-Data Science\New folder\Task_1_Stocks_dataset.csv")
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# <b> Step 3: Preprocess the Data

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %% [markdown]
# <b>Step 4: Prepare the Data for LSTM Model

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# <b>STEP 5 : CREATING LSTM MODEL

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50, 50)            10600
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 5s 55ms/step - loss: 0.0066 - mean_absolute_error: 0.0572 - val_loss: 0.0142 - val_mean_absolute_error: 0.0932
# Epoch 2/100
# 28/28 [==============================] - 1s 32ms/step - loss: 7.9673e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0092 - val_mean_absolute_error: 0.0775
# Epoch 3/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.6504e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0041 - val_mean_absolute_error: 0.0481
# Epoch 4/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.5276e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0062 - val_mean_absolute_error: 0.0614
# Epoch 5/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.4003e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0058 - val_mean_absolute_error: 0.0597
# Epoch 6/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.3990e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0046 - val_mean_absolute_error: 0.0514
# Epoch 7/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.5455e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0036 - val_mean_absolute_error: 0.0451
# Epoch 8/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.4508e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0051 - val_mean_absolute_error: 0.0549
# Epoch 9/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.0671e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0063 - val_mean_absolute_error: 0.0630
# Epoch 10/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.1413e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0049 - val_mean_absolute_error: 0.0539
# Epoch 11/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.6280e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0059 - val_mean_absolute_error: 0.0613
# Epoch 12/100
# 28/28 [==============================] - 1s 36ms/step - loss: 4.1784e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0046 - val_mean_absolute_error: 0.0519
# Epoch 13/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.5030e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 14/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.4676e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0053 - val_mean_absolute_error: 0.0578
# Epoch 15/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.2295e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0043 - val_mean_absolute_error: 0.0503
# Epoch 16/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.3358e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0050 - val_mean_absolute_error: 0.0548
# Epoch 17/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.1703e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0063 - val_mean_absolute_error: 0.0623
# Epoch 18/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.1008e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0052 - val_mean_absolute_error: 0.0559
# Epoch 19/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.0144e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0091 - val_mean_absolute_error: 0.0784
# Epoch 20/100
# 28/28 [==============================] - 1s 39ms/step - loss: 3.3820e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0056 - val_mean_absolute_error: 0.0592
# Epoch 21/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.8298e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0038 - val_mean_absolute_error: 0.0448
# Epoch 22/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.8380e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0061 - val_mean_absolute_error: 0.0619
# Epoch 23/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.9582e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0037 - val_mean_absolute_error: 0.0450
# Epoch 24/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.7163e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0054 - val_mean_absolute_error: 0.0559
# Epoch 25/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.7195e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0054 - val_mean_absolute_error: 0.0541
# Epoch 26/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.8186e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0070 - val_mean_absolute_error: 0.0685
# Epoch 27/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.8058e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0032 - val_mean_absolute_error: 0.0413
# Epoch 28/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.4398e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0030 - val_mean_absolute_error: 0.0404
# Epoch 29/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.7364e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0037 - val_mean_absolute_error: 0.0462
# Epoch 30/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.4572e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0051 - val_mean_absolute_error: 0.0561
# Epoch 31/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.3313e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0052 - val_mean_absolute_error: 0.0574
# Epoch 32/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.2832e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 33/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.2010e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 34/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.0611e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0025 - val_mean_absolute_error: 0.0375
# Epoch 35/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.1318e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0042 - val_mean_absolute_error: 0.0520
# Epoch 36/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.1995e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0025 - val_mean_absolute_error: 0.0372
# Epoch 37/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.1512e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0031 - val_mean_absolute_error: 0.0413
# Epoch 38/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.0273e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0014 - val_mean_absolute_error: 0.0267
# Epoch 39/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.0734e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0035 - val_mean_absolute_error: 0.0467
# Epoch 40/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.9141e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0398
# Epoch 41/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.0295e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 42/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.9225e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 43/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.9964e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 44/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.8281e-04 - mean_absolute_error: 0.0099 - val_loss: 8.5487e-04 - val_mean_absolute_error: 0.0209
# Epoch 45/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.8520e-04 - mean_absolute_error: 0.0099 - val_loss: 8.9947e-04 - val_mean_absolute_error: 0.0213
# Epoch 46/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.8347e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0031 - val_mean_absolute_error: 0.0459
# Epoch 47/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.7811e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
# Epoch 48/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.7419e-04 - mean_absolute_error: 0.0099 - val_loss: 7.8020e-04 - val_mean_absolute_error: 0.0199
# Epoch 49/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.7775e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0017 - val_mean_absolute_error: 0.0300
# Epoch 50/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.5829e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0254
# Epoch 51/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.7379e-04 - mean_absolute_error: 0.0096 - val_loss: 9.3444e-04 - val_mean_absolute_error: 0.0216
# Epoch 52/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.5914e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 53/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.6166e-04 - mean_absolute_error: 0.0094 - val_loss: 9.9166e-04 - val_mean_absolute_error: 0.0222
# Epoch 54/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.5031e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0039 - val_mean_absolute_error: 0.0533
# Epoch 55/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.5996e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0021 - val_mean_absolute_error: 0.0341
# Epoch 56/100
# 28/28 [==============================] - 1s 36ms/step - loss: 1.4735e-04 - mean_absolute_error: 0.0088 - val_loss: 9.4488e-04 - val_mean_absolute_error: 0.0221
# Epoch 57/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.4720e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 58/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.4892e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0021 - val_mean_absolute_error: 0.0358
# Epoch 59/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.6617e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0029 - val_mean_absolute_error: 0.0430
# Epoch 60/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.4318e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 61/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.3984e-04 - mean_absolute_error: 0.0086 - val_loss: 8.7929e-04 - val_mean_absolute_error: 0.0209
# Epoch 62/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.4512e-04 - mean_absolute_error: 0.0088 - val_loss: 5.5557e-04 - val_mean_absolute_error: 0.0174
# Epoch 63/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.3226e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 64/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.3152e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 65/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.2727e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 66/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.4057e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0021 - val_mean_absolute_error: 0.0343
# Epoch 67/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.3672e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0018 - val_mean_absolute_error: 0.0304
# Epoch 68/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.2087e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 69/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.3273e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 70/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.1580e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0012 - val_mean_absolute_error: 0.0246
# Epoch 71/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.2802e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0015 - val_mean_absolute_error: 0.0279
# Epoch 72/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.2367e-04 - mean_absolute_error: 0.0079 - val_loss: 9.7048e-04 - val_mean_absolute_error: 0.0227
# Epoch 73/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.3122e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 74/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.1985e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 75/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.1818e-04 - mean_absolute_error: 0.0078 - val_loss: 9.8340e-04 - val_mean_absolute_error: 0.0222
# Epoch 76/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.4988e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 77/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.0948e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 78/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.2699e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 79/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.1471e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 80/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.2202e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 81/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.2495e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 82/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.1608e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 83/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.1598e-04 - mean_absolute_error: 0.0076 - val_loss: 9.0509e-04 - val_mean_absolute_error: 0.0214
# Epoch 84/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.0786e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 85/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.0850e-04 - mean_absolute_error: 0.0074 - val_loss: 8.6291e-04 - val_mean_absolute_error: 0.0219
# Epoch 86/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.2866e-04 - mean_absolute_error: 0.0083 - val_loss: 9.1745e-04 - val_mean_absolute_error: 0.0223
# Epoch 87/100
# 28/28 [==============================] - 1s 36ms/step - loss: 1.1346e-04 - mean_absolute_error: 0.0077 - val_loss: 7.7260e-04 - val_mean_absolute_error: 0.0204
# Epoch 88/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.1453e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 89/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.0199e-04 - mean_absolute_error: 0.0071 - val_loss: 8.4931e-04 - val_mean_absolute_error: 0.0205
# Epoch 90/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.0508e-04 - mean_absolute_error: 0.0071 - val_loss: 6.9692e-04 - val_mean_absolute_error: 0.0187
# Epoch 91/100
# 28/28 [==============================] - 1s 38ms/step - loss: 9.7682e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283
# Epoch 92/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.1012e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0034 - val_mean_absolute_error: 0.0491
# Epoch 93/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.0313e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 94/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.1621e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251
# Epoch 95/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.0208e-04 - mean_absolute_error: 0.0072 - val_loss: 5.2555e-04 - val_mean_absolute_error: 0.0171
# Epoch 96/100
# 28/28 [==============================] - 1s 37ms/step - loss: 9.7448e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251
# Epoch 97/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.0025e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0016 - val_mean_absolute_error: 0.0317
# Epoch 98/100
# 28/28 [==============================] - 1s 37ms/step - loss: 9.5888e-05 - mean_absolute_error: 0.0068 - val_loss: 8.0863e-04 - val_mean_absolute_error: 0.0218
# Epoch 99/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.0645e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0016 - val_mean_absolute_error: 0.0327
# Epoch 100/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.0101e-04 - mean_absolute_error: 0.0070 - val_loss: 8.7434e-04 - val_mean_absolute_error: 0.0218

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 12ms/step
# array([[0.40378246, 0.4038858 ],
#        [0.4028773 , 0.403261  ],
#        [0.39901283, 0.39966616],
#        [0.40464896, 0.4049791 ],
#        [0.4083361 , 0.4085382 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[0.40378246, 0.4038858 ],
#        [0.4028773 , 0.403261  ],
#        [0.39901283, 0.39966616],
#        [0.40464896, 0.4049791 ],
#        [0.4083361 , 0.4085382 ]], dtype=float32)

# %% [markdown]
# <b>STEP 6 :  VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                 open     close  open_predicted  close_predicted
# date
# 2020-05-27  0.402525  0.404448        0.403782         0.403886
# 2020-05-28  0.391527  0.403849        0.402877         0.403261
# 2020-05-29  0.402358  0.410427        0.399013         0.399666
# 2020-06-01  0.403140  0.411991        0.404649         0.404979
# 2020-06-02  0.409699  0.415984        0.408336         0.408538

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# <b>STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                 open     close  open_predicted  close_predicted
# 2021-06-09  0.986289  0.983705        0.949119         0.915229
# 2021-06-10  0.983327  1.000000        0.953399         0.919307
# 2021-06-11  1.000000  0.995862        0.962652         0.927980
# 2021-06-12       NaN       NaN             NaN              NaN
# 2021-06-13       NaN       NaN             NaN              NaN
# 2021-06-14       NaN       NaN             NaN              NaN
# 2021-06-15       NaN       NaN             NaN              NaN
# 2021-06-16       NaN       NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
